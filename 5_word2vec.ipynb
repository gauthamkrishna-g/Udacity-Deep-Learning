# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print("Found and verified %s" % filename)
    else:
        print(statinfo.st_size)
        raise Exception("Failed to verify " + filename + ". Can you get to it with a browser?")
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print("Data size %d" % len(words))
# Out:
# Data size 17005207

# %%
print (words[:50])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print("Most common words (+UNK)", count[:5])
print("Sample data", data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [skip_window target skip_window]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print("data:", [reverse_dictionary[di] for di in data[:15]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print("\nwith num_skips = %d and skip_window = %d:" % (num_skips, skip_window))
    print("    batch:", [reverse_dictionary[bi] for bi in batch])
    print("    labels:", [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], \
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, \
                                                     inputs=embed, labels=train_labels, \
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step %d: %f" % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.418837
# Nearest to which: booked, abbeys, bonewits, transducers, taino, disputed, squadrons, pled,
# Nearest to state: hairstyle, assign, jahn, ligaments, vi, brockovich, dyer, cathal,
# Nearest to this: carlson, thelma, astra, maximus, sadly, skim, bestiary, flux,
# Nearest to than: clarified, livy, swine, hoofed, indonesia, fumimaro, tigers, broke,
# Nearest to between: provocative, funds, logo, ascii, narrative, eminem, usenet, sped,
# Nearest to be: meuse, akrotiri, tectonics, kansas, firepower, brittle, remedy, grab,
# Nearest to all: dramas, given, anticipated, oui, neo, guild, aurora, overline,
# Nearest to one: northampton, data, wound, dymaxion, motels, john, auditioned, budgetary,
# Nearest to three: motte, raster, rubies, sojourn, hispanics, barney, fermat, imposition,
# Nearest to seven: verdi, churchman, novelist, plesiosaur, ups, riga, bovary, primed,
# Nearest to during: belt, udi, useful, roswell, muller, recite, caledonia, kolbe,
# Nearest to new: pretender, alight, johnstone, videotaped, imposes, victorian, long, impractical,
# Nearest to and: mucus, saudi, mohs, gdr, flinders, geldof, nawaf, episcopalians,
# Nearest to have: mr, guoyu, bubi, ek, regain, crookes, fundamentalists, priorities,
# Nearest to i: handbooks, mdi, clotting, authentic, lunda, throne, adult, preconceptions,
# Nearest to or: knitters, gilda, mtu, sophie, howland, injury, venerable, scotland,
# Average loss at step 2000: 4.368233
# Average loss at step 4000: 3.867046
# Average loss at step 6000: 3.786763
# Average loss at step 8000: 3.694692
# Average loss at step 10000: 3.617025
# Nearest to which: that, this, it, alex, jehu, centralize, engagements, who,
# Nearest to state: diss, selden, list, brockovich, nd, assign, jahn, rohde,
# Nearest to this: it, the, which, that, unsuitable, a, unfiltered, bestiary,
# Nearest to than: livy, spheres, strict, lass, curium, dig, kalinga, for,
# Nearest to between: sped, usenet, provocative, logo, ascii, foci, spawn, funds,
# Nearest to be: have, micro, meuse, are, grab, lovell, was, is,
# Nearest to all: guild, witnessed, given, kate, beth, yaoi, adornment, chojn,
# Nearest to one: three, two, four, six, eight, seven, five, zero,
# Nearest to three: six, four, five, seven, eight, two, zero, nine,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to during: belt, in, after, optimize, first, on, ech, quasi,
# Nearest to new: pretender, johnstone, alight, main, impractical, victorian, imposes, videotaped,
# Nearest to and: or, manors, s, b, secrecy, glorioso, wankel, who,
# Nearest to have: had, has, be, are, were, altar, dhole, irian,
# Nearest to i: lunda, authentic, they, mdi, preconceptions, evacuated, breakage, handbooks,
# Nearest to or: and, screenshot, venerable, futhark, requiem, vive, s, startling,
# Average loss at step 12000: 3.607165
# Average loss at step 14000: 3.574584
# Average loss at step 16000: 3.417515
# Average loss at step 18000: 3.456678
# Average loss at step 20000: 3.541311
# Nearest to which: this, that, also, who, it, what, alex, but,
# Nearest to state: diss, assign, jahn, nd, elaborates, brockovich, spirit, selden,
# Nearest to this: it, which, the, that, some, a, unsuitable, delight,
# Nearest to than: or, dig, clarified, livy, lass, variability, fansite, slavs,
# Nearest to between: sped, from, with, foci, through, logo, in, into,
# Nearest to be: have, been, is, meuse, micro, was, by, were,
# Nearest to all: many, these, some, both, fostered, beth, witnessed, sail,
# Nearest to one: four, two, seven, three, six, eight, five, nine,
# Nearest to three: five, four, six, seven, eight, two, zero, nine,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to during: after, in, belt, quasi, among, biopsy, under, cbs,
# Nearest to new: pretender, alight, victorian, main, imposes, roh, gladys, honeycomb,
# Nearest to and: or, but, in, anconia, which, from, near, like,
# Nearest to have: had, has, be, are, were, altar, dhole, ovid,
# Nearest to i: louis, ii, ihs, kush, alton, lea, stf, pca,
# Nearest to or: and, demokratische, than, decks, minor, thither, takeover, venerable,
# Average loss at step 22000: 3.504797
# Average loss at step 24000: 3.489529
# Average loss at step 26000: 3.485362
# Average loss at step 28000: 3.483467
# Average loss at step 30000: 3.502468
# Nearest to which: this, that, who, what, also, it, usually, but,
# Nearest to state: diss, government, brockovich, elaborates, assign, gorilla, nd, jahn,
# Nearest to this: it, which, what, unsuitable, that, darkest, jerzy, bestiary,
# Nearest to than: or, automorphism, celebrities, clarified, fansite, huey, downs, dig,
# Nearest to between: with, in, from, sped, foci, kerala, against, over,
# Nearest to be: been, have, is, meuse, moran, are, columba, were,
# Nearest to all: some, both, these, many, machinima, caribou, argue, useable,
# Nearest to one: two, four, seven, eight, five, three, six, nine,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to seven: eight, nine, five, four, six, three, zero, two,
# Nearest to during: after, in, under, belt, from, at, on, kolbe,
# Nearest to new: victorian, pretender, honeycomb, johnstone, impractical, alight, trick, third,
# Nearest to and: or, but, in, anconia, who, irregularly, however, milit,
# Nearest to have: had, has, are, were, be, altar, having, transceiver,
# Nearest to i: ii, you, ihs, we, louis, they, kush, ut,
# Nearest to or: and, than, marbury, but, demokratische, secrecy, decks, taking,
# Average loss at step 32000: 3.504525
# Average loss at step 34000: 3.493996
# Average loss at step 36000: 3.456359
# Average loss at step 38000: 3.305328
# Average loss at step 40000: 3.423783
# Nearest to which: that, this, who, also, usually, what, often, it,
# Nearest to state: government, diss, brockovich, regions, superfund, foodstuff, jahn, intellivision,
# Nearest to this: it, which, that, the, darkest, what, any, jerzy,
# Nearest to than: or, automorphism, isaiah, huey, weep, variability, clarified, spheres,
# Nearest to between: with, sped, over, from, foci, against, hinted, heterotic,
# Nearest to be: been, is, moran, have, was, meuse, were, are,
# Nearest to all: both, some, many, any, these, ark, machinima, forgetful,
# Nearest to one: seven, eight, six, two, four, five, three, nine,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to during: after, at, on, under, in, before, from, upon,
# Nearest to new: victorian, menagerie, third, honeycomb, pretender, sanjaks, trunk, alight,
# Nearest to and: or, but, waldseem, in, footnotes, polanyi, like, are,
# Nearest to have: had, has, were, are, be, unready, antagonist, glaucus,
# Nearest to i: you, ii, we, they, he, she, t, pca,
# Nearest to or: and, than, thither, biollante, demokratische, screenshot, gaddis, taking,
# Average loss at step 42000: 3.430158
# Average loss at step 44000: 3.459599
# Average loss at step 46000: 3.450712
# Average loss at step 48000: 3.354946
# Average loss at step 50000: 3.384759
# Nearest to which: this, that, also, who, what, usually, these, often,
# Nearest to state: government, diss, pensions, elaborates, regions, brockovich, intellivision, constituents,
# Nearest to this: which, it, the, some, jahn, he, catholicism, that,
# Nearest to than: or, automorphism, huey, but, mails, clarified, flooding, complicated,
# Nearest to between: with, through, against, in, sped, from, over, eminem,
# Nearest to be: was, been, have, being, is, were, are, meuse,
# Nearest to all: both, many, some, bolster, these, beth, any, caribou,
# Nearest to one: eight, two, six, seven, four, five, nine, three,
# Nearest to three: six, seven, four, eight, two, five, nine, zero,
# Nearest to seven: eight, six, nine, three, four, five, zero, two,
# Nearest to during: after, in, under, at, before, when, from, leftist,
# Nearest to new: victorian, third, pretender, menagerie, retake, trunk, great, buccaneer,
# Nearest to and: or, but, anconia, editorship, s, of, herbivore, manors,
# Nearest to have: had, has, were, are, be, having, find, paging,
# Nearest to i: we, ii, you, t, ihs, he, oxidize, they,
# Nearest to or: and, than, thither, decks, courson, dravidians, midday, xxv,
# Average loss at step 52000: 3.436564
# Average loss at step 54000: 3.428003
# Average loss at step 56000: 3.441536
# Average loss at step 58000: 3.397635
# Average loss at step 60000: 3.398221
# Nearest to which: that, this, what, who, it, usually, however, also,
# Nearest to state: government, diss, pensions, states, intellivision, envision, regions, jahn,
# Nearest to this: which, it, that, some, the, there, what, jerzy,
# Nearest to than: and, or, but, automorphism, huey, much, claymore, emerges,
# Nearest to between: with, among, through, over, against, sped, within, eminem,
# Nearest to be: been, is, have, was, become, moran, being, persuaded,
# Nearest to all: many, both, some, any, various, these, each, those,
# Nearest to one: eight, two, four, six, five, seven, three, nine,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to during: after, in, before, when, within, at, under, following,
# Nearest to new: victorian, pretender, menagerie, honeycomb, landon, coriander, nominal, trunk,
# Nearest to and: or, but, than, including, waldseem, like, marbury, ddrmax,
# Nearest to have: has, had, having, are, be, were, require, contain,
# Nearest to i: ii, we, you, ihs, t, oxidize, g, custis,
# Nearest to or: and, than, mitsubishi, interdisciplinarity, resource, oracular, but, like,
# Average loss at step 62000: 3.237742
# Average loss at step 64000: 3.255243
# Average loss at step 66000: 3.403054
# Average loss at step 68000: 3.401213
# Average loss at step 70000: 3.360244
# Nearest to which: that, this, what, also, usually, saffron, these, but,
# Nearest to state: government, states, diss, jahn, selden, republic, pra, foal,
# Nearest to this: it, which, the, that, another, what, there, jerzy,
# Nearest to than: automorphism, or, churchland, huey, but, fansite, apologised, and,
# Nearest to between: with, from, among, within, in, anatolian, around, through,
# Nearest to be: been, is, being, have, were, become, was, columba,
# Nearest to all: many, some, both, any, various, these, whereof, each,
# Nearest to one: two, six, seven, four, five, eight, nine, three,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to during: after, within, before, in, under, following, until, at,
# Nearest to new: pretender, menagerie, landon, victorian, coriander, coda, princeto, cohn,
# Nearest to and: or, editorship, which, while, anconia, but, like, however,
# Nearest to have: had, has, were, are, require, having, be, include,
# Nearest to i: you, ii, we, g, oxidize, t, ihs, custis,
# Nearest to or: and, amman, rarities, than, any, onlookers, decks, deadly,
# Average loss at step 72000: 3.376137
# Average loss at step 74000: 3.350585
# Average loss at step 76000: 3.324692
# Average loss at step 78000: 3.354066
# Average loss at step 80000: 3.379504
# Nearest to which: that, this, also, usually, saffron, who, located, often,
# Nearest to state: government, states, city, diss, pensions, republic, jahn, unsympathetic,
# Nearest to this: it, which, the, jerzy, jahn, what, another, purcell,
# Nearest to than: but, or, much, automorphism, and, complicated, huey, trivia,
# Nearest to between: among, with, within, around, over, across, through, sped,
# Nearest to be: been, have, become, being, was, is, meuse, continue,
# Nearest to all: both, many, any, some, various, outside, every, several,
# Nearest to one: seven, six, two, four, three, five, eight, nine,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to during: after, in, before, within, when, under, until, through,
# Nearest to new: victorian, menagerie, pretender, honeycomb, coda, gladys, single, kansas,
# Nearest to and: or, but, while, editorship, including, tapioca, than, manors,
# Nearest to have: had, has, are, were, having, be, require, include,
# Nearest to i: ii, you, we, t, g, ihs, custis, oxidize,
# Nearest to or: and, than, amman, dravidians, intervals, while, courson, wed,
# Average loss at step 82000: 3.405561
# Average loss at step 84000: 3.411388
# Average loss at step 86000: 3.394353
# Average loss at step 88000: 3.352773
# Average loss at step 90000: 3.360768
# Nearest to which: that, this, also, usually, what, who, these, both,
# Nearest to state: government, city, states, diss, stimulation, pensions, chicks, salvator,
# Nearest to this: it, which, the, jerzy, some, symbolic, another, catastrophe,
# Nearest to than: or, automorphism, huey, churchland, complicated, much, but, ethidium,
# Nearest to between: among, with, within, through, sped, across, around, in,
# Nearest to be: been, become, was, have, continue, being, is, are,
# Nearest to all: both, many, some, outside, several, various, any, every,
# Nearest to one: seven, four, eight, two, six, five, nine, three,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to seven: five, eight, six, four, nine, three, zero, one,
# Nearest to during: after, in, within, before, under, from, through, at,
# Nearest to new: victorian, negation, menagerie, pretender, maybe, transaction, coda, dwindling,
# Nearest to and: or, but, while, marbury, nonexistent, including, asic, however,
# Nearest to have: had, has, were, require, are, having, include, be,
# Nearest to i: ii, you, we, g, t, ihs, kent, breakage,
# Nearest to or: and, than, emerges, fujiwara, amman, dravidians, but, futhark,
# Average loss at step 92000: 3.402301
# Average loss at step 94000: 3.253541
# Average loss at step 96000: 3.357184
# Average loss at step 98000: 3.248770
# Average loss at step 100000: 3.358867
# Nearest to which: that, this, usually, who, these, what, but, saffron,
# Nearest to state: government, city, states, aqueduct, debt, stimulation, schizophrenic, georgia,
# Nearest to this: it, which, the, another, symbolic, some, itself, jahn,
# Nearest to than: or, and, churchland, slavs, automorphism, much, huey, complicated,
# Nearest to between: with, among, through, within, against, sped, across, anatolian,
# Nearest to be: been, become, being, have, refer, persuaded, continue, are,
# Nearest to all: some, various, many, any, several, these, both, every,
# Nearest to one: two, seven, four, eight, six, five, nine, three,
# Nearest to three: five, four, seven, six, two, eight, nine, zero,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to during: in, after, before, within, following, under, when, since,
# Nearest to new: victorian, transaction, landon, gladys, pretender, roh, besieging, irreverent,
# Nearest to and: or, but, marbury, including, while, although, when, however,
# Nearest to have: had, has, were, require, include, are, having, tend,
# Nearest to i: you, we, ii, t, he, freeways, they, g,
# Nearest to or: and, than, pronoun, amman, screenshot, causing, tha, cleansed,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    # assert batch_size % num_skips == 0
    # assert num_skips <= 2 * skip_window
    span = 2 * bag_window + 1 # [bag_window target bag_window]
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print("data:", [reverse_dictionary[di] for di in data[:15]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print("\nbag_window = %d:" % (bag_window))
    print("    batch:", [[reverse_dictionary[w] for w in bi] for bi in batch])
    print("    labels:", [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including']
#
# bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
# skip_window = 1 # How many words to consider left and right.
# num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many times to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], \
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, \
                                                     inputs=tf.reduce_sum(embeds, 1), labels=train_labels, \
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step %d: %f" % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.347363
# Nearest to that: wit, statehouse, hilberg, contemporaneous, rhein, novgorod, instructional, supermodel,
# Nearest to into: honorius, appeal, sandworm, aba, mission, threat, rudder, pago,
# Nearest to may: goose, jpl, dozens, bethesda, elfman, vol, subdivided, myr,
# Nearest to all: median, unlucky, millionaire, storybook, grammy, brutus, customary, remittances,
# Nearest to used: ncp, wished, whitlam, oses, af, twilight, australians, primate,
# Nearest to will: tear, manages, maka, tintin, forthcoming, oda, danzig, rhodesia,
# Nearest to but: xhtml, sharing, kantian, bekenstein, fertilizers, tensions, spit, norodom,
# Nearest to more: cutaway, portmanteaus, darrow, infinitesimal, res, less, abv, amos,
# Nearest to for: persians, molly, bets, sighted, chapelle, identity, solvable, museum,
# Nearest to see: blender, polymerase, letterboxes, diseases, triode, rdos, inge, martinique,
# Nearest to many: bedrock, profusion, qualifying, fd, ideologue, witold, mastermind, hectares,
# Nearest to would: trend, optics, mintz, lebrun, chattanooga, regulated, kronecker, dale,
# Nearest to called: southey, taino, strengthened, lester, shelton, official, fried, clocking,
# Nearest to five: deo, fats, connotes, canter, resuming, activator, queens, salaam,
# Nearest to by: password, unlucky, rubidium, salinger, cephalopods, coincided, preconceptions, memel,
# Nearest to as: som, sulfides, laughed, hymenoptera, ethan, leiber, counternarcotics, rangers,
# Average loss at step 2000: 4.604688
# Average loss at step 4000: 3.936106
# Average loss at step 6000: 3.720940
# Average loss at step 8000: 3.530176
# Average loss at step 10000: 3.477356
# Nearest to that: which, when, parastatal, stereoisomers, password, reining, who, seedlings,
# Nearest to into: during, from, colonised, digweed, instalments, within, falsehood, ssi,
# Nearest to may: can, could, would, should, will, might, must, to,
# Nearest to all: many, several, minstrels, these, unconsciousness, lms, leucine, some,
# Nearest to used: considered, found, known, seen, described, hera, appointees, discovered,
# Nearest to will: would, can, should, may, could, must, to, relieve,
# Nearest to but: blore, oxycoccus, although, chrismation, prerecorded, merci, pharmacy, monasteries,
# Nearest to more: less, most, rather, other, anime, bmc, jonas, ambience,
# Nearest to for: ousted, bongo, of, unmanned, with, joanne, founds, regrets,
# Nearest to see: dwarfed, organizers, lesson, conduit, grapevine, triode, martinique, tans,
# Nearest to many: some, several, all, these, other, most, validation, various,
# Nearest to would: could, can, may, will, should, to, might, cannot,
# Nearest to called: stabilize, cic, psychometric, sequencer, ironworks, woogie, dativus, telegrams,
# Nearest to five: four, seven, three, zero, six, nine, eight, two,
# Nearest to by: persists, who, throughout, zeeland, gorgias, precipitating, hexokinase, with,
# Nearest to as: rowena, aventine, computes, evacuated, fertilisation, sniff, bladed, incite,
# Average loss at step 12000: 3.477429
# Average loss at step 14000: 3.434625
# Average loss at step 16000: 3.437099
# Average loss at step 18000: 3.400025
# Average loss at step 20000: 3.220929
# Nearest to that: which, where, this, what, if, when, yar, however,
# Nearest to into: through, between, from, patass, colonised, mba, within, in,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to all: interment, many, both, these, champions, any, several, sed,
# Nearest to used: considered, known, described, seen, found, referred, available, responsible,
# Nearest to will: would, could, should, may, can, must, might, does,
# Nearest to but: and, however, though, although, umberto, than, where, sarabande,
# Nearest to more: less, rather, most, better, very, larger, greater, faster,
# Nearest to for: after, notebooks, while, when, behind, cynics, radiodiffusion, sniff,
# Nearest to see: dwarfed, includes, kev, octal, panza, arranges, affects, called,
# Nearest to many: some, several, various, these, most, all, those, numerous,
# Nearest to would: could, will, should, may, might, can, must, did,
# Nearest to called: known, considered, korps, cic, bon, aswan, deemed, market,
# Nearest to five: six, zero, seven, four, three, eight, two, nine,
# Nearest to by: budding, ingersoll, throughout, among, lymph, rollout, infocom, recitation,
# Nearest to as: pr, id, chagas, shallow, fulfil, computes, slid, knight,
# Average loss at step 22000: 3.359523
# Average loss at step 24000: 3.288728
# Average loss at step 26000: 3.251458
# Average loss at step 28000: 3.281183
# Average loss at step 30000: 3.224680
# Nearest to that: which, what, where, this, yar, if, who, ararat,
# Nearest to into: through, within, from, between, in, consequently, thus, down,
# Nearest to may: can, must, would, should, could, might, will, cannot,
# Nearest to all: some, many, any, every, those, both, several, interment,
# Nearest to used: referred, described, considered, seen, designed, called, viewed, available,
# Nearest to will: would, could, can, must, should, may, might, does,
# Nearest to but: and, however, although, though, than, see, because, until,
# Nearest to more: less, rather, better, very, larger, faster, most, greater,
# Nearest to for: notebooks, before, bongo, behind, after, molly, disaccharide, through,
# Nearest to see: includes, called, but, include, limestones, lopez, monogram, breeches,
# Nearest to many: some, several, various, most, these, all, numerous, list,
# Nearest to would: could, should, will, can, may, must, might, did,
# Nearest to called: used, considered, named, known, see, deemed, gherkin, bon,
# Nearest to five: four, three, seven, six, zero, nine, eight, two,
# Nearest to by: turnips, augmentation, yue, rulebook, through, infocom, protium, glories,
# Nearest to as: masturbation, pr, cubewanos, chagas, tice, mahendra, like, har,
# Average loss at step 32000: 3.012665
# Average loss at step 34000: 3.203956
# Average loss at step 36000: 3.186353
# Average loss at step 38000: 3.157637
# Average loss at step 40000: 3.165407
# Nearest to that: which, however, although, where, seedlings, this, because, indiscriminately,
# Nearest to into: through, within, from, down, between, waterline, rarities, digweed,
# Nearest to may: can, could, should, must, would, will, might, cannot,
# Nearest to all: every, various, many, certain, some, any, several, both,
# Nearest to used: considered, referred, seen, described, known, played, required, performed,
# Nearest to will: would, should, could, may, must, can, might, cannot,
# Nearest to but: however, although, than, though, and, while, colonist, norte,
# Nearest to more: less, better, rather, very, larger, faster, greater, smaller,
# Nearest to for: after, bongo, reining, joanne, since, during, vassalage, notebooks,
# Nearest to see: includes, limestones, known, semiconductors, include, halted, but, morocco,
# Nearest to many: several, some, various, all, numerous, most, few, certain,
# Nearest to would: will, could, should, may, might, must, can, did,
# Nearest to called: considered, used, named, known, deemed, bon, awm, included,
# Nearest to five: six, eight, four, seven, three, nine, zero, two,
# Nearest to by: when, draper, infocom, nana, protium, yue, through, persists,
# Nearest to as: computes, kanagawa, valentine, uneconomic, frictional, tice, pr, gebhard,
# Average loss at step 42000: 3.208761
# Average loss at step 44000: 3.139119
# Average loss at step 46000: 3.138471
# Average loss at step 48000: 3.054087
# Average loss at step 50000: 3.055941
# Nearest to that: which, however, although, where, ararat, what, because, this,
# Nearest to into: within, through, from, between, in, around, digweed, disintegrating,
# Nearest to may: can, could, must, would, should, might, will, cannot,
# Nearest to all: many, several, various, some, these, any, every, grasped,
# Nearest to used: referred, considered, seen, described, found, available, required, employed,
# Nearest to will: would, could, must, should, can, may, might, cannot,
# Nearest to but: though, although, than, however, unheard, umberto, and, rallied,
# Nearest to more: less, rather, better, most, very, quite, larger, greater,
# Nearest to for: behind, unregulated, joanne, without, of, unmanned, founds, vajrayana,
# Nearest to see: includes, chandler, morocco, libertarian, itt, catal, shameful, include,
# Nearest to many: some, several, various, all, numerous, certain, these, few,
# Nearest to would: will, could, may, should, might, must, can, cannot,
# Nearest to called: used, deemed, considered, named, bon, awm, known, required,
# Nearest to five: six, seven, four, zero, eight, three, nine, two,
# Nearest to by: through, turnips, undermines, infocom, nana, rollout, zhuhai, scarlett,
# Nearest to as: auratus, how, chagas, grafton, hildebrand, comrades, computes, slid,
# Average loss at step 52000: 3.093063
# Average loss at step 54000: 3.088758
# Average loss at step 56000: 2.917712
# Average loss at step 58000: 3.024897
# Average loss at step 60000: 3.053619
# Nearest to that: which, where, what, when, because, seedlings, martins, however,
# Nearest to into: from, within, onto, through, inside, digweed, rallied, rhodope,
# Nearest to may: can, must, might, could, would, should, will, cannot,
# Nearest to all: many, multiple, some, several, various, certain, both, these,
# Nearest to used: considered, seen, referred, known, described, employed, regarded, called,
# Nearest to will: would, could, must, should, may, might, can, cannot,
# Nearest to but: and, though, than, however, although, umberto, until, while,
# Nearest to more: less, very, rather, most, quite, greater, extremely, larger,
# Nearest to for: notebooks, joanne, behind, founds, crowe, after, without, reining,
# Nearest to see: includes, references, include, contain, turboprop, serpents, arranges, require,
# Nearest to many: some, several, various, numerous, all, these, most, certain,
# Nearest to would: will, could, might, may, should, must, can, did,
# Nearest to called: considered, used, named, referred, held, defined, described, created,
# Nearest to five: six, seven, eight, three, four, zero, nine, two,
# Nearest to by: through, gorgias, turnips, infocom, draper, augmentation, rollout, under,
# Nearest to as: lantern, slid, gebhard, computes, augmentation, pane, masturbation, esso,
# Average loss at step 62000: 3.012380
# Average loss at step 64000: 2.926384
# Average loss at step 66000: 2.932629
# Average loss at step 68000: 2.957859
# Average loss at step 70000: 3.007390
# Nearest to that: which, where, this, what, seedlings, plh, although, because,
# Nearest to into: within, from, through, across, onto, sisterhood, down, rhodope,
# Nearest to may: might, can, could, must, should, would, will, cannot,
# Nearest to all: many, multiple, various, several, certain, every, both, some,
# Nearest to used: employed, referred, available, seen, required, considered, found, known,
# Nearest to will: must, would, should, can, could, might, may, cannot,
# Nearest to but: though, although, while, and, which, than, however, because,
# Nearest to more: less, greater, very, rather, better, most, quite, too,
# Nearest to for: after, joanne, vassalage, typologically, founds, despite, without, crickets,
# Nearest to see: includes, catal, contains, saw, require, subsist, contain, allows,
# Nearest to many: some, several, various, numerous, all, both, thousands, these,
# Nearest to would: will, might, could, may, should, must, can, did,
# Nearest to called: considered, named, used, termed, deemed, described, held, played,
# Nearest to five: six, seven, four, three, eight, zero, two, nine,
# Nearest to by: through, infocom, hexokinase, gorgias, draper, yue, rollout, leaflets,
# Nearest to as: har, finegold, mcg, auratus, like, slid, pane, valentine,
# Average loss at step 72000: 2.930101
# Average loss at step 74000: 2.859105
# Average loss at step 76000: 3.005990
# Average loss at step 78000: 3.007118
# Average loss at step 80000: 2.844554
# Nearest to that: which, however, seedlings, where, indeed, how, what, condominium,
# Nearest to into: within, through, across, onto, from, down, between, mineralogist,
# Nearest to may: might, can, could, should, must, will, would, cannot,
# Nearest to all: many, various, some, both, any, several, multiple, every,
# Nearest to used: referred, available, employed, found, designed, described, seen, required,
# Nearest to will: would, could, should, must, might, can, may, cannot,
# Nearest to but: though, although, however, while, and, because, see, yet,
# Nearest to more: less, very, rather, greater, most, extremely, quite, better,
# Nearest to for: without, joanne, after, founds, behind, verdeans, vassalage, antipsychotic,
# Nearest to see: includes, catal, but, called, known, include, correlate, require,
# Nearest to many: some, several, various, numerous, all, both, certain, most,
# Nearest to would: will, could, might, should, must, may, can, did,
# Nearest to called: named, considered, used, played, referred, described, termed, see,
# Nearest to five: six, seven, three, four, eight, nine, zero, two,
# Nearest to by: through, infocom, draper, yue, without, when, who, turnips,
# Nearest to as: pane, auratus, lantern, hildebrand, har, precluded, valentine, computes,
# Average loss at step 82000: 2.935158
# Average loss at step 84000: 2.901464
# Average loss at step 86000: 2.917792
# Average loss at step 88000: 2.943256
# Average loss at step 90000: 2.827926
# Nearest to that: which, where, what, when, seedlings, this, condominium, ararat,
# Nearest to into: through, within, across, onto, from, down, between, off,
# Nearest to may: can, might, could, will, should, must, would, cannot,
# Nearest to all: both, various, many, certain, some, any, multiple, every,
# Nearest to used: referred, designed, required, employed, available, performed, added, needed,
# Nearest to will: would, should, must, might, can, could, may, cannot,
# Nearest to but: though, however, although, while, see, norte, and, displayed,
# Nearest to more: less, rather, quite, too, very, better, extremely, greater,
# Nearest to for: after, without, joanne, typologically, reining, founds, spraying, behind,
# Nearest to see: includes, contains, but, catal, allows, known, provides, generalissimo,
# Nearest to many: some, several, various, numerous, both, all, certain, thousands,
# Nearest to would: will, might, could, can, may, must, should, cannot,
# Nearest to called: named, considered, used, termed, known, referred, described, introduced,
# Nearest to five: six, seven, eight, four, three, zero, nine, two,
# Nearest to by: through, when, cartier, rollout, richelieu, yue, undermines, leaflets,
# Nearest to as: har, crying, gp, variadic, chagas, sniff, pane, eyewitness,
# Average loss at step 92000: 2.892100
# Average loss at step 94000: 2.880456
# Average loss at step 96000: 2.710355
# Average loss at step 98000: 2.463301
# Average loss at step 100000: 2.708202
# Nearest to that: which, where, when, because, how, although, condominium, whom,
# Nearest to into: through, across, within, onto, from, down, off, in,
# Nearest to may: might, should, could, must, would, can, cannot, will,
# Nearest to all: every, various, some, many, both, multiple, any, several,
# Nearest to used: referred, applied, seen, designed, employed, added, known, performed,
# Nearest to will: would, should, could, must, might, can, cannot, shall,
# Nearest to but: however, though, and, although, while, than, or, monegasque,
# Nearest to more: less, rather, faster, very, better, greater, quite, larger,
# Nearest to for: after, despite, joanne, antipsychotic, without, regrets, founds, severn,
# Nearest to see: includes, catal, refer, contains, allow, references, goi, contain,
# Nearest to many: several, some, various, numerous, both, thousands, all, most,
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to called: named, considered, termed, used, referred, deemed, held, policing,
# Nearest to five: three, seven, six, four, eight, zero, two, nine,
# Nearest to by: through, without, hexokinase, atl, cartier, yue, from, disquiet,
# Nearest to as: chagas, slid, pane, har, sniff, computes, mamma, grafton,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
